# %%
import pandas as pd
df = pd.read_csv("/Volumes/epgp_aai_aai/ai_schema/ai_volume/matplotlib-seaborn-files/APAGAI - C1M2 - Recall Quiz - File - 1/swiggy.csv")
df

# %%
df.loc[df['Price'] > 1000, ['Restaurant', 'Price']]

# %%
df.loc[df['Price'] > 1000, :]

# %%
df.loc[df['Price'] > 1000, 'Restaurant', 'Price']

# %%
df.loc['Price' > 1000, ['Restaurant', 'Price']]

# %%
df.loc[(df['Avg ratings'] > 4.5) & (df['Total ratings'] >= 200), :]

# %%
df.loc[:, (df['Avg ratings'] > 4.5) & (df['Total ratings'] >= 200)]

# %%
df.loc[(df['Food type'].str.contains('Biryani')) & (df['City'] == 'Bangalore'), ['Restaurant', 'Price', 'Food type']]

# %%
df.loc[(df['Food type'].str.contains('Biryani') & df['City'] == 'Bangalore'), ['Restaurant', 'Price', 'Food type']]

# %%
df['Discounted Price'] = df['Price'].apply(lambda price: 0.95*price if price > 1000 else price)
df

# %%
df.loc[(df['Discounted Price'] == df['Price']),['Price','Discounted Price']]

# %%
df_price = df.loc[(df['City'] == 'Bangalore'),['Price']]
df_price.describe()

# %%
df['City'].nunique()

# %%
len(df['City'].unique())

# %%
len(df['City'].nunique())

# %%
len(set(df['City']))

# %%
df['Avg ratings'] = df.apply(lambda row: row['Avg ratings'] - 0.5 if row['Total ratings'] <= 100 else row['Avg ratings'])

# %%
df['Avg ratings'] = df.apply(lambda row: row['Avg ratings'] - 0.5 if row['Total ratings'] <= 100 else row['Avg ratings'], axis = 1)
df

# %%
df.loc[df['City'] == 'Bangalore', 'City'] = 'Bengaluru'
df

# %%
display(df.groupby('City')['Price'].sum().reset_index())

# %%
display(df.groupby('City')['Total ratings'].sum().reset_index())
